# %% [markdown]
# # Downloading information from WRDS for the company *FrieslandCampina*
#
# ### The data is from Bureau van Dijk(BvD)'s database Amadeus, concerning only European companies
#
# * Link to the Wharton's website: [WRDS](https://wrds-web.wharton.upenn.edu/wrds/)

# %%
import wrds
import pandas as pd
from sqlalchemy import create_engine, text

#establishing connection
db = wrds.Connection(wrds_username ='tycho1')
# Out:
# Loading library list...
# Done

# %%
db.list_libraries()
# Out:
# ['public',
#  'wrds_lib_internal',
#  'centris',
#  'gsi',
#  'rent',
#  'wrdsapps',
#  'wrdsapps_evtravtaq',
#  'wrdsapps_finratios',
#  'eureka',
#  'ims',
#  'ktmine',
#  'secsamp_all_new',
#  'compnad',
#  'twoiq',
#  'frb_all_new',
#  'ginsight',
#  'crsp_a_ziman',
#  'crsp_q_ziman',
#  'blab',
#  'lspd',
#  'ravenpack_trial',
#  'optionmsamp_us',
#  'optionmsamp_europe',
#  'ff_all_new',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_q_ccm',
#  'crsp_q_indexes',
#  'trws',
#  'crsp_q_stock',
#  'bvd_osiris',
#  'risk_governance',
#  'secsamp',
#  'levin',
#  'risk_directors',
#  'tass',
#  'hfr',
#  'ims_obp_trial',
#  'macrofin_comm_trade',
#  'comp_segments_hist',
#  'audit_audit_comp',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'compm',
#  'ktmine_patents_samp',
#  'macrofin',
#  'crspa',
#  'boardex_trial',
#  'comp_bank',
#  'compb',
#  'snlsamp_fig',
#  'ftse',
#  'audit',
#  'etfg_samp',
#  'csmar',
#  'etfgsamp',
#  'dealscan',
#  'bvd_ama_large',
#  'compa',
#  'bvd_ama_small',
#  'bvd_ama_medium',
#  'bvd_ama_verylarge',
#  'tr_ibes',
#  'compsamp_snapshot',
#  'ppubsamp_d4d',
#  'mrktsamp_msf',
#  'eurekahedge_sample',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'factsamp_revere',
#  'hfrsamp_hfrdb',
#  'calcbench_trial',
#  'contrib_char_returns',
#  'aha_sample',
#  'clrvtsmp',
#  'doe',
#  'calcbnch',
#  'msrb',
#  'ahasamp',
#  'frb',
#  'dmef',
#  'block',
#  'pwt',
#  'wrdsrpts_rep_usage',
#  'twoiq_samp',
#  'contrib',
#  'cboe',
#  'ff',
#  'phlx',
#  'djones',
#  'trace_enhanced',
#  'totalq',
#  'reprisk_sample',
#  'wrdsrpts',
#  'ibes',
#  'crsp',
#  'sdc',
#  'risk_proposals',
#  'crspq',
#  'trace_standard',
#  'etfg',
#  'trace',
#  'bvd',
#  'iss_va_shareholder',
#  'comp_global',
#  'compg',
#  'ciq_common',
#  'ciq',
#  'ibescorp',
#  'comp_execucomp',
#  'clrvt',
#  'compdcur',
#  'execcomp',
#  'kld_histall',
#  'kld',
#  'tr_insiders',
#  'tfn',
#  'risk',
#  'etfg_samp_new',
#  'compgd',
#  'taqmsec',
#  'comp_global_daily',
#  'compd',
#  'taqm_2018',
#  'revere',
#  'comp_bank_daily',
#  'compbd',
#  'comp_segments_hist_daily',
#  'comp',
#  'compseg',
#  'compsegd',
#  'zacks',
#  'msfinst',
#  'otc_endofday',
#  'msfanly',
#  'wrdssec',
#  'otc',
#  'markit']

# %%
db.list_tables('bvd')
# Out:
# ['osiris_qvards',
#  'os_activ_asicuscde',
#  'os_activ_ftinclas',
#  'os_activ_nace2scde',
#  'os_activ_nacescde',
#  'os_activ_naics12cde',
#  'os_activ_paics12cod',
#  'os_activ_pnace2cd',
#  'os_activ_pnacecd',
#  'os_activ_psicuscde',
#  'os_do',
#  'os_fin_bnk',
#  'os_fin_ind',
#  'os_fin_ins',
#  'os_gen',
#  'os_gen_advisor',
#  'os_gen_manager',
#  'os_io',
#  'os_shh',
#  'os_stock_exchanges',
#  'os_stock_header',
#  'os_stock_indexes',
#  'os_stock_monthly',
#  'os_stock_ratios',
#  'os_stock_weekly',
#  'os_sub',
#  'os_uo',
#  'bankscope_qvards',
#  'bs_bank',
#  'bs_companions',
#  'bs_directors',
#  'bs_financials',
#  'bs_ish_guo_duo',
#  'bs_overview',
#  'bs_shareholders',
#  'bs_stock_annual',
#  'bs_stock_current',
#  'bs_stock_indexes',
#  'bs_stock_info',
#  'bs_stock_monthly',
#  'bs_stock_places',
#  'bs_stock_weekly',
#  'bs_subsidiaries',
#  'is_alsoknown',
#  'is_auditors',
#  'is_duo',
#  'is_fin_com',
#  'is_fin_lif',
#  'is_fin_nl',
#  'is_formerknown',
#  'is_gen',
#  'is_io',
#  'is_managers',
#  'is_ownhdr',
#  'is_shh',
#  'is_stock_exchanges',
#  'is_stock_header',
#  'is_stock_indexes',
#  'is_stock_ratios',
#  'is_stock_weekly',
#  'is_sub',
#  'is_uo',
#  'isis_qvards',
#  'ob_ind_g_fins_usd_l',
#  'ob_ind_g_fins_eur_l',
#  'ob_cflow_non_us_ind_eur_l',
#  'ob_contact_info_l',
#  'ob_industry_classifications_l',
#  'ob_fin_strength_crif_l',
#  'ob_banks_g_fins_int_l',
#  'ob_cflow_us_ind_eur_l',
#  'ob_bankers_previous_l',
#  'ob_trade_description_l',
#  'ob_cflow_us_ind_l',
#  'ob_banks_g_fins_usd_l',
#  'ob_ind_g_fins_usd_int_l',
#  'ob_detailed_fmt_ind_int_l',
#  'ob_all_subs_first_level_l',
#  'ob_detailed_fmt_ind_eur_l',
#  'ob_other_advisors_current_l',
#  'ob_controlling_shareholders_l',
#  'ob_detailed_fmt_ind_eur_int_l',
#  'ob_detailed_fmt_ind_usd_int_l',
#  'ob_ins_g_fins_eur_l',
#  'ob_identifiers_l',
#  'ob_fin_strength_more_l',
#  'ob_cflow_non_us_ind_usd_l',
#  'ob_dmc_previous_l',
#  'ob_w_ind_g_fins_cfl_usd_l',
#  'ob_all_cur_shh_1st_level_l',
#  'ob_w_ind_g_fins_cfl_usd_int_l',
#  'ob_detailed_fmt_ind_usd_l',
#  'ob_ind_g_fins_l',
#  'ob_basic_shareholder_info_l',
#  'ob_key_financials_l',
#  'ob_fin_strength_bvd_valu_l',
#  'ob_cflow_us_ind_usd_int_l',
#  'ob_cflow_us_ind_usd_l',
#  'ob_bankers_current_l',
#  'ob_cflow_non_us_ind_usd_int_l',
#  'ob_ind_g_fins_int_l',
#  'ob_auditors_current_l',
#  'ob_detailed_fmt_ind_l',
#  'ob_all_addresses_l',
#  'ob_cflow_non_us_ind_eur_int_l',
#  'ob_banks_g_fins_usd_int_l',
#  'ob_fin_strength_trucost_l',
#  'ob_additional_company_info_l',
#  'ob_cflow_non_us_ind_l',
#  'ob_hq_l',
#  'ob_cflow_non_us_ind_int_l',
#  'ob_cflow_us_ind_interim_l',
#  'ob_ins_g_fins_usd_l',
#  'ob_banks_g_fins_l',
#  'ob_key_financials_eur_l',
#  'ob_banks_g_fins_eur_int_l',
#  'ob_branches_l',
#  'ob_ins_g_fins_l',
#  'ob_cflow_us_ind_eur_int_l',
#  'ob_fin_strength_vadis_l',
#  'ob_key_financials_usd_l',
#  'ob_ind_g_fins_eur_int_l',
#  'ob_legal_info_l',
#  'ob_w_company_id_table_l',
#  'ob_fin_strength_zanders_l',
#  'ob_dmc_current_only_l',
#  'ob_banks_g_fins_eur_l',
#  'ob_ins_g_fins_m',
#  'ob_cflow_non_us_ind_usd_m',
#  'ob_dmc_previous_m',
#  'ob_additional_company_info_m',
#  'ob_auditors_current_m',
#  'ob_banks_g_fins_m',
#  'ob_detailed_fmt_ind_int_m',
#  'ob_detailed_fmt_ind_m',
#  'ob_key_financials_m',
#  'ob_key_financials_usd_m',
#  'ob_cflow_us_ind_eur_m',
#  'ob_cflow_us_ind_interim_m',
#  'ob_contact_info_m',
#  'ob_hq_m',
#  'ob_ind_g_fins_eur_int_m',
#  'ob_ind_g_fins_m',
#  'ob_ind_g_fins_usd_m',
#  'ob_ins_g_fins_eur_m',
#  'ob_w_ind_g_fins_cfl_usd_int_m',
#  'ob_all_subs_first_level_lm',
#  'ob_banks_g_fins_eur_int_m',
#  'ob_fin_strength_crif_m',
#  'ob_cflow_non_us_ind_m',
#  'ob_legal_info_m',
#  'ob_cflow_us_ind_m',
#  'ob_w_ind_g_fins_cfl_usd_lm',
#  'ob_cflow_non_us_ind_int_m',
#  'ob_banks_g_fins_int_m',
#  'ob_fin_strength_more_m',
#  'ob_banks_g_fins_usd_int_m',
#  'ob_fin_strength_bvd_valu_m',
#  'ob_cflow_non_us_ind_usd_int_m',
#  'ob_bankers_current_m',
#  'ob_bankers_previous_m',
#  'ob_detailed_fmt_ind_usd_int_m',
#  'ob_fin_strength_trucost_m',
#  'ob_ins_g_fins_usd_lm',
#  'ob_ins_g_fins_usd_m',
#  'ob_key_financials_eur_m',
#  'ob_cflow_us_ind_eur_int_m',
#  'ob_cflow_us_ind_usd_int_m',
#  'ob_ind_g_fins_int_m',
#  'ob_industry_classifications_m',
#  'ob_banks_g_fins_usd_int_lm',
#  'ob_banks_g_fins_usd_m',
#  'ob_basic_shareholder_info_m',
#  'ob_branches_m',
#  'ob_cflow_non_us_ind_eur_int_m',
#  'ob_cflow_non_us_ind_eur_m',
#  'ob_w_company_id_table_lm',
#  'ob_w_ind_g_fins_cfl_usd_m',
#  'ob_all_cur_shh_1st_level_lm',
#  'ob_fin_strength_zanders_m',
#  'ob_trade_description_m',
#  'ob_all_addresses_m',
#  'ob_ind_g_fins_eur_m',
#  'ob_detailed_fmt_ind_eur_int_m',
#  'ob_controlling_shareholders_m',
#  'ob_ind_g_fins_usd_int_m',
#  'ob_cflow_us_ind_usd_m',
#  'ob_all_subs_first_level_m',
#  'ob_w_company_id_table_m',
#  'ob_fin_strength_vadis_m',
#  'ob_banks_g_fins_eur_m',
#  'ob_identifiers_m',
#  'ob_w_ind_g_fins_cfl_usd_int_lm',
#  'ob_all_cur_shh_1st_level_m',
#  'ob_banks_g_fins_usd_lm',
#  'ob_detailed_fmt_ind_usd_m',
#  'ob_dmc_current_only_m',
#  'ob_other_advisors_current_m',
#  'ob_detailed_fmt_ind_eur_m',
#  'ob_ind_g_fins_usd_s',
#  'ob_trade_description_s',
#  'ob_key_financials_eur_s',
#  'ob_additional_company_info_s',
#  'ob_fin_strength_zanders_s',
#  'ob_w_ind_g_fins_cfl_usd_int_s',
#  'ob_basic_shareholder_info_s',
#  'ob_detailed_fmt_ind_usd_s',
#  'ob_ins_g_fins_usd_lms',
#  'ob_identifiers_s',
#  'ob_all_cur_shh_1st_level_s',
#  'ob_all_subs_first_level_s',
#  'ob_banks_g_fins_usd_s',
#  'ob_industry_classifications_s',
#  'ob_cflow_non_us_ind_eur_int_s',
#  'ob_legal_info_s',
#  'ob_cflow_us_ind_eur_s',
#  'ob_w_ind_g_fins_cfl_usd_int_lms',
#  'ob_hq_s',
#  'ob_detailed_fmt_ind_usd_int_s',
#  'ob_fin_strength_bvd_valu_s',
#  'ob_banks_g_fins_usd_lms',
#  'ob_key_financials_usd_s',
#  'ob_fin_strength_vadis_s',
#  'ob_cflow_us_ind_eur_int_s',
#  'ob_fin_strength_crif_s',
#  'ob_w_ind_g_fins_cfl_usd_s',
#  'ob_cflow_non_us_ind_int_s',
#  'ob_banks_g_fins_usd_int_lms',
#  'ob_w_ind_g_fins_cfl_usd_lms',
#  'ob_cflow_us_ind_s',
#  'ob_fin_strength_trucost_s',
#  'ob_controlling_shareholders_s',
#  'ob_detailed_fmt_ind_eur_int_s',
#  'ob_detailed_fmt_ind_eur_s',
#  'ob_detailed_fmt_ind_int_s',
#  'ob_w_company_id_table_s',
#  'ob_banks_g_fins_usd_int_s',
#  'ob_ind_g_fins_eur_int_s',
#  'ob_cflow_non_us_ind_s',
#  'ob_cflow_non_us_ind_usd_int_s',
#  'ob_auditors_current_s',
#  'ob_bankers_previous_s',
#  'ob_cflow_us_ind_usd_int_s',
#  'ob_banks_g_fins_int_s',
#  'ob_branches_s',
#  'ob_ind_g_fins_s',
#  'ob_ind_g_fins_usd_int_s',
#  'ob_banks_g_fins_eur_int_s',
#  'ob_detailed_fmt_ind_s',
#  'ob_ind_g_fins_eur_s',
#  'ob_ins_g_fins_eur_s',
#  'ob_dmc_previous_s',
#  'ob_contact_info_s',
#  'ob_ins_g_fins_s',
#  'ob_ind_g_fins_int_s',
#  'ob_other_advisors_current_s',
#  'ob_all_addresses_s',
#  'ob_all_cur_shh_1st_level_lms',
#  'orbis_qvards',
#  'ob_ins_g_fins_usd_s',
#  'ob_key_financials_s',
#  'ob_all_subs_first_level_lms',
#  'ob_cflow_us_ind_usd_s',
#  'ob_banks_g_fins_eur_s',
#  'ob_cflow_non_us_ind_usd_s',
#  'ob_cflow_us_ind_interim_s',
#  'ob_cflow_non_us_ind_eur_s',
#  'ob_bankers_current_s',
#  'ob_dmc_current_only_s',
#  'ob_w_company_id_table_lms',
#  'ob_banks_g_fins_s',
#  'ob_fin_strength_more_s',
#  'activities_l',
#  'amadeus_l',
#  'auditors_l',
#  'bankers_l',
#  'company_l',
#  'financials_l',
#  'ish_duo_guo_l',
#  'managers_l',
#  'overview_l',
#  'shareholders_l',
#  'stock_annual_l',
#  'stock_current_l',
#  'stock_indexes_l',
#  'stock_info_l',
#  'stock_monthly_l',
#  'stock_places_l',
#  'stock_weekly_l',
#  'subsidiaries_l',
#  'websites_l',
#  'activities_m',
#  'amadeus_m',
#  'auditors_m',
#  'bankers_m',
#  'company_m',
#  'financials_m',
#  'ish_duo_guo_m',
#  'managers_m',
#  'overview_m',
#  'shareholders_m',
#  'stock_annual_m',
#  'stock_current_m',
#  'stock_indexes_m',
#  'stock_info_m',
#  'stock_monthly_m',
#  'stock_places_m',
#  'stock_weekly_m',
#  'subsidiaries_m',
#  'websites_m',
#  'activities_v',
#  'amadeus_qvards',
#  'amadeus_v',
#  'auditors_v',
#  'bankers_v',
#  'company_v',
#  'financials_v',
#  'ish_duo_guo_v',
#  'managers_v',
#  'overview_v',
#  'shareholders_v',
#  'stock_annual_v',
#  'stock_current_v',
#  'stock_indexes_v',
#  'stock_info_v',
#  'stock_monthly_v',
#  'stock_places_v',
#  'stock_weekly_v',
#  'subsidiaries_v',
#  'websites_v',
#  'activities_s',
#  'amadeus_s',
#  'auditors_s',
#  'bankers_s',
#  'company_s',
#  'financials_s',
#  'ish_duo_guo_s',
#  'managers_s',
#  'overview_s',
#  'shareholders_s',
#  'stock_annual_s',
#  'stock_current_s',
#  'stock_indexes_s',
#  'stock_info_s',
#  'stock_monthly_s',
#  'stock_places_s',
#  'stock_weekly_s',
#  'subsidiaries_s',
#  'websites_s',
#  'bvdbankf_regulators',
#  'bvdbankf_directors',
#  'bvdbankf_qvards',
#  'bvdbankf_stock_weekly',
#  'bvdbankf_stock_monthly',
#  'bvdbankf_ish_guo_duo',
#  'bvdbankf_subsidiaries',
#  'bvdbankf_stock_current',
#  'bvdbankf_stock_info',
#  'bvdbankf_companions',
#  'bvdbankf_branches_headquarters',
#  'bvdbankf_bank',
#  'bvdbankf_stock_annual',
#  'bvdbankf_shareholders',
#  'bvdbankf_overview',
#  'bvdbankf_stock_places',
#  'bvdbankf_financials',
#  'bvdbankf_stock_indexes']

# %%
db.describe_table(library='bvd', table='financials_l')
# Out:
# Approximately 3529400 rows in bvd.financials_l.
#              name  nullable              type
# 0            idnr      True       VARCHAR(15)
# 1         country      True       VARCHAR(22)
# 2          repbas      True       VARCHAR(24)
# 3        closdate      True              DATE
# 4   closdate_year      True  DOUBLE PRECISION
# 5          accpra      True       VARCHAR(10)
# 6          months      True  DOUBLE PRECISION
# 7            unit      True  DOUBLE PRECISION
# 8        currency      True        VARCHAR(3)
# 9        exchrate      True  DOUBLE PRECISION
# 10      exchrate2      True  DOUBLE PRECISION
# 11           fias      True  DOUBLE PRECISION
# 12           ifas      True  DOUBLE PRECISION
# 13           tfas      True  DOUBLE PRECISION
# 14           ofas      True  DOUBLE PRECISION
# 15           cuas      True  DOUBLE PRECISION
# 16           stok      True  DOUBLE PRECISION
# 17           debt      True  DOUBLE PRECISION
# 18           ocas      True  DOUBLE PRECISION
# 19           cash      True  DOUBLE PRECISION
# 20           toas      True  DOUBLE PRECISION
# 21           shfd      True  DOUBLE PRECISION
# 22           capi      True  DOUBLE PRECISION
# 23           osfd      True  DOUBLE PRECISION
# 24           ncli      True  DOUBLE PRECISION
# 25           ltdb      True  DOUBLE PRECISION
# 26           oncl      True  DOUBLE PRECISION
# 27           prov      True  DOUBLE PRECISION
# 28           culi      True  DOUBLE PRECISION
# 29           loan      True  DOUBLE PRECISION
# ..            ...       ...               ...
# 60             av      True  DOUBLE PRECISION
# 61           ebit      True  DOUBLE PRECISION
# 62           ebta      True  DOUBLE PRECISION
# 63           rshf      True  DOUBLE PRECISION
# 64           rcem      True  DOUBLE PRECISION
# 65           rtas      True  DOUBLE PRECISION
# 66           cfop      True  DOUBLE PRECISION
# 67           prma      True  DOUBLE PRECISION
# 68           grma      True  DOUBLE PRECISION
# 69           etma      True  DOUBLE PRECISION
# 70           ebma      True  DOUBLE PRECISION
# 71            nat      True  DOUBLE PRECISION
# 72             ic      True  DOUBLE PRECISION
# 73           stot      True  DOUBLE PRECISION
# 74           coll      True  DOUBLE PRECISION
# 75           crpe      True  DOUBLE PRECISION
# 76           exop      True  DOUBLE PRECISION
# 77           curr      True  DOUBLE PRECISION
# 78           liqr      True  DOUBLE PRECISION
# 79           shlq      True  DOUBLE PRECISION
# 80           solr      True  DOUBLE PRECISION
# 81           gear      True  DOUBLE PRECISION
# 82            ppe      True  DOUBLE PRECISION
# 83            tpe      True  DOUBLE PRECISION
# 84            sct      True  DOUBLE PRECISION
# 85            ace      True  DOUBLE PRECISION
# 86           sfpe      True  DOUBLE PRECISION
# 87           wcpe      True  DOUBLE PRECISION
# 88           tape      True  DOUBLE PRECISION
# 89        compcat      True       VARCHAR(12)
#
# [90 rows x 3 columns]

# %%
#downloading small companies
dfFriesland_s = db.raw_sql(text("SELECT bf.*,bc.*, \
                                 REPLACE(bc.name,'FRIESLANDCAMPINA','FRICAMP') AS name_short \
                                 FROM bvd.financials_s as bf  \
                                 INNER JOIN bvd.company_s as bc \
                                 ON bf.idnr = bc.idnr \
                                 WHERE bc.name LIKE '%FRIESLANDCAMPINA%' ; "))

# %%
#downloading medium size companies
dfFriesland_m = db.raw_sql(text("SELECT bf.*,bc.*, \
                                 REPLACE(bc.name,'FRIESLANDCAMPINA','FRICAMP') AS name_short \
                                 FROM bvd.financials_m as bf  \
                                 INNER JOIN bvd.company_m as bc \
                                 ON bf.idnr = bc.idnr \
                                 WHERE bc.name LIKE '%FRIESLANDCAMPINA%' ; "))

# %%
#downloading large size companies
dfFriesland_l = db.raw_sql(text("SELECT *, \
                                 REPLACE(bc.name,'FRIESLANDCAMPINA','FRICAMP') AS name_short \
                                 FROM bvd.financials_l as bf  \
                                 INNER JOIN bvd.company_l as bc \
                                 ON bf.idnr = bc.idnr \
                                 WHERE bc.name LIKE '%FRIESLANDCAMPINA%' ; "))

# %%
#downloading very large size companies
dfFriesland_v = db.raw_sql(text("SELECT bf.*,bc.*, \
                                 REPLACE(bc.name,'FRIESLANDCAMPINA','FRICAMP') AS name_short \
                                 FROM bvd.financials_v as bf  \
                                 INNER JOIN bvd.company_v as bc \
                                 ON bf.idnr = bc.idnr \
                                 WHERE bc.name LIKE '%FRIESLANDCAMPINA%' ; "))

# %%
#the names of the companies
dfFriesland_names = db.raw_sql(text("SELECT bc.name, bc.idnr \
                                    FROM bvd.company_l as bc \
                                    WHERE bc.name LIKE 'FRIESLANDCAMPINA%' ; "))

# %%
# combining the 4 dataframes into one
df = dfFriesland_s.append(dfFriesland_m)
df = df.append(dfFriesland_l)
df = df.append(dfFriesland_v)

# %%
df.to_csv(r'Dropbox/mytest.csv') #saving to csv file

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

sns.lineplot(x="closdate_year",y="gear",hue="name_short",data = df[["closdate_year","gear","name_short"]].dropna())

# %%
sns.lineplot(x="closdate_year",y="solr",hue="name_short",data = df[["closdate_year","solr","name_short"]].dropna())

# %% [markdown]
# ### Here is a link to a Tableau Story/Dashboard with analysis of the data downloaded in this notebook
#
# [link to Tableau](https://public.tableau.com/profile/tihomir7992#!/vizhome/FrieslandCampina_subsidiaries_Europe/Story1)
